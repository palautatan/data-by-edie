# %% [markdown]
# **3. Sociogram & Network Construction**
# Objective: Map the digital alliance structure and social "gravity" of the cast.
# Pipeline:
# - Construct adjacency matrix of contestant co-mentions.
# - Calculate Network Centrality (Degree, Betweenness, Eigenvector) to identify bridge-builders vs. main-character anchors.
# - Apply Louvain Clustering to group contestants by "Subreddit Perception Communities."
