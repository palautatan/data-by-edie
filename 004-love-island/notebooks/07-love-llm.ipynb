# %% [markdown]
# **LLM Narrative Distillation: Per-week synthesis of contestant discourse.**
# - Generate a structured Sentiment Score (1–5 Likert scale).
# - Generate synthetic "Lover" vs. "Hater" perspectives to capture qualitative community nuance.
